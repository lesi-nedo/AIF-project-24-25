# %% [markdown]
# # **Oleksiy's Problog Agent Analysis**

# %% [markdown]
# ### Libraries

# %%
from analyse import analyse, analyze_inference_and_actions

# %% [markdown]
# ### Marco's Mcts Agent vs Oleksiy's Problog Agent

# %%
# math_files = glob.glob('stats/MctsAi-vs-ProblogAgent/match-*.json')
analyse('stats_k=2/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats_k=2/MctsAi-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0530 seconds
# Median Inference Time: 0.0358 seconds
# Total Actions Analyzed: 57467

# %% [markdown]
# ### FightingICE's Mcts Agent vs Oleksiy's Problog Agent

# %%
analyse('stats/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats/MctsAi23i-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0330 seconds
# Median Inference Time: 0.0275 seconds
# Total Actions Analyzed: 31058

# %% [markdown]
# ### Simone's Prolog Agent vs Oleksiy's Problog Agent

# %%
analyse('stats/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Win Rate: 100.00%
# Loss Rate: 0.00%

# %%
analyze_inference_and_actions('stats/PrologAI-vs-ProblogAgent/match-*.json')
# Out:
# Detailed Statistics:
# Action Mismatch Rate: 100.00%
# Average Inference Time: 0.0339 seconds
# Median Inference Time: 0.0278 seconds
# Total Actions Analyzed: 25104
